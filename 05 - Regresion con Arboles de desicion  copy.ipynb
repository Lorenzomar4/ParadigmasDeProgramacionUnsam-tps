# %%
import pickle

# Cargar la variable desde el archivo
with open('variable.pkl', 'rb') as f:
    algoPrediccion = pickle.load(f)

# %% [markdown]
# # Regresión con Árboles de Decisión

# %%
from algoritmos import  ReresionConArboles
from sklearn.tree import DecisionTreeRegressor
algoPrediccion.algoritmo = ReresionConArboles(DecisionTreeRegressor(random_state = 0))
algoPrediccion.realizarEntrenamientoSinDivisionDeConjuntos()
algoPrediccion.resultadoDeEntrenamiento()
# Out:
#        Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# 0        4733     4620.00          113.00                         2.39
# 1        6424     7036.00          612.00                         9.53
# 2        5510     4404.00         1106.00                        20.07
# 3        8770    11302.00         2532.00                        28.87
# 4        4493     4678.00          185.00                         4.12
# ...       ...         ...             ...                          ...
# 10783    1289     1385.00           96.00                         7.45
# 10784    3435     3189.00          246.00                         7.16
# 10785    3847     4244.00          397.00                        10.32
# 10786    8168     8317.00          149.00                         1.82
# 10787    1917     2105.00          188.00                         9.81
#
# [10788 rows x 4 columns]

# %%
algoPrediccion.resultadoDeEntrenamiento().describe()
# Out:
#         Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# count 10788.00    10788.00        10788.00                     10788.00
# mean   3929.21     3925.62          370.18                         9.69
# std    3981.60     3989.45          669.83                        10.10
# min     326.00      338.00            0.00                         0.00
# 25%     947.50      946.00           47.00                         1.98
# 50%    2398.00     2391.00          145.00                         6.45
# 75%    5311.25     5273.00          376.25                        14.36
# max   18787.00    18818.00        10424.00                       135.25

# %%
algoPrediccion.todasLasComparacionesDeActualPrediccion()

# %%
algoPrediccion.conclusiones()
# Out:
#                             Media  Error %  Efectividad %
# Mean Absolute Error        370.18     9.41          90.59
# Root Mean Squared Error    765.28    19.46          80.54
# Mean Squared Error      585660.47      NaN            NaN
