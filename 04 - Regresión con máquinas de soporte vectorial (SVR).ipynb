# %%
import pickle

# Cargar la variable desde el archivo
with open('variable.pkl', 'rb') as f:
    algoPrediccion = pickle.load(f)

# %% [markdown]
# # Regresión con máquinas de soporte vectorial (SVR)

# %% [markdown]
# ## Kernel : rbf

# %%
from sklearn.svm import SVR
from algoritmos import  RegresionSVR

svr_rbf = SVR(kernel="rbf",epsilon=0.1)
svr_lin = SVR(kernel="linear" ,gamma="auto")
svr_poly = SVR(kernel="poly", gamma="auto", degree=3, epsilon=0.1, coef0=1)


algoPrediccion.algoritmo = RegresionSVR(svr_rbf) 
algoPrediccion.realizarEntrenamientoSinDivisionDeConjuntos()
algoPrediccion.resultadoDeEntrenamiento()
# Out:
#        Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# 0        4733     4735.81            2.81                         0.06
# 1        6424     7229.74          805.74                        12.54
# 2        5510     5251.74          258.26                         4.69
# 3        8770    11535.76         2765.76                        31.54
# 4        4493     4854.00          361.00                         8.03
# ...       ...         ...             ...                          ...
# 10783    1289     1082.64          206.36                        16.01
# 10784    3435     3261.35          173.65                         5.06
# 10785    3847     4533.74          686.74                        17.85
# 10786    8168     7767.49          400.51                         4.90
# 10787    1917     2068.11          151.11                         7.88
#
# [10788 rows x 4 columns]

# %%
algoPrediccion.resultadoDeEntrenamiento().describe()
# Out:
#         Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# count 10788.00    10788.00        10788.00                     10788.00
# mean   3929.21     3937.21          358.82                        13.34
# std    3981.60     3944.48          531.77                        15.50
# min     326.00      -26.35            0.01                         0.00
# 25%     947.50      923.84           92.39                         3.95
# 50%    2398.00     2448.92          206.67                         8.80
# 75%    5311.25     5402.39          389.24                        17.60
# max   18787.00    21724.01        10399.45                       663.92

# %%
algoPrediccion.todasLasComparacionesDeActualPrediccion()

# %%
algoPrediccion.conclusiones()
# Out:
#                             Media  Error %  Efectividad %
# Mean Absolute Error        358.82     9.12          90.88
# Root Mean Squared Error    641.49    16.31          83.69
# Mean Squared Error      411505.78      NaN            NaN

# %% [markdown]
# ## Kernel : Poly

# %%
algoPrediccion.algoritmo = RegresionSVR(svr_poly)  ##Se probo previamente con otros grados .Pero el de 3 da peor resultado y el de grado 4 tarda demasiado
algoPrediccion.realizarEntrenamientoSinDivisionDeConjuntos()
algoPrediccion.resultadoDeEntrenamiento()
# Out:
#        Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# 0        4733     4786.23           53.23                         1.12
# 1        6424     7300.78          876.78                        13.65
# 2        5510     5324.11          185.89                         3.37
# 3        8770    11384.52         2614.52                        29.81
# 4        4493     4847.57          354.57                         7.89
# ...       ...         ...             ...                          ...
# 10783    1289     1299.22           10.22                         0.79
# 10784    3435     3292.11          142.89                         4.16
# 10785    3847     4640.11          793.11                        20.62
# 10786    8168     7686.86          481.14                         5.89
# 10787    1917     1786.63          130.37                         6.80
#
# [10788 rows x 4 columns]

# %%
algoPrediccion.resultadoDeEntrenamiento().describe()
# Out:
#         Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# count 10788.00    10788.00        10788.00                     10788.00
# mean   3929.21     3945.58          354.77                        13.87
# std    3981.60     3979.08          537.83                        15.57
# min     326.00    -2933.42            0.02                         0.00
# 25%     947.50      943.05           96.32                         3.91
# 50%    2398.00     2397.19          209.75                         8.85
# 75%    5311.25     5410.26          383.23                        17.84
# max   18787.00    25940.46        16320.42                       154.38

# %%
algoPrediccion.todasLasComparacionesDeActualPrediccion()

# %%
algoPrediccion.conclusiones()
# Out:
#                             Media  Error %  Efectividad %
# Mean Absolute Error        354.77     9.02          90.98
# Root Mean Squared Error    644.28    16.38          83.62
# Mean Squared Error      415090.99      NaN            NaN

# %% [markdown]
# # Kernel Linear

# %%
from sklearn.svm import SVR
from algoritmos import  RegresionSVR


algoPrediccion.algoritmo = RegresionSVR(svr_lin)  
algoPrediccion.realizarEntrenamientoSinDivisionDeConjuntos()
algoPrediccion.resultadoDeEntrenamiento()
# Out:
#        Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# 0        4733     4943.57          210.57                         4.45
# 1        6424     7411.29          987.29                        15.37
# 2        5510     6013.26          503.26                         9.13
# 3        8770     9853.37         1083.37                        12.35
# 4        4493     4795.40          302.40                         6.73
# ...       ...         ...             ...                          ...
# 10783    1289     1296.29            7.29                         0.57
# 10784    3435     3524.40           89.40                         2.60
# 10785    3847     5062.41         1215.41                        31.59
# 10786    8168     6260.43         1907.57                        23.35
# 10787    1917     1904.70           12.30                         0.64
#
# [10788 rows x 4 columns]

# %%
algoPrediccion.resultadoDeEntrenamiento().describe()
# Out:
#         Actual  Prediccion  Error Absoluta  Error porcentual absoluto %
# count 10788.00    10788.00        10788.00                     10788.00
# mean   3929.21     3822.05          658.74                        28.11
# std    3981.60     3725.32          966.42                        43.70
# min     326.00    -3101.21            0.00                         0.00
# 25%     947.50     1066.41          186.63                         7.16
# 50%    2398.00     2580.00          366.00                        15.83
# 75%    5311.25     5621.17          694.17                        31.93
# max   18787.00    34888.66        17559.66                       591.32

# %%
algoPrediccion.todasLasComparacionesDeActualPrediccion()

# %%
algoPrediccion.conclusiones()
# Out:
#                              Media  Error %  Efectividad %
# Mean Absolute Error         658.74    16.75          83.25
# Root Mean Squared Error    1169.54    29.74          70.26
# Mean Squared Error      1367813.06      NaN            NaN
